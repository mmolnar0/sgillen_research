# %% [markdown]
# This notebook compares vanilla RNNs (SimpleRNN in keras) to an LSTM for the cartpole swingup

# %%
# Force keras to use the CPU becuase it's actually faster for this size network
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"] = ""

import numpy as np
import pandas as pd

from numpy import cos, sin, pi
import matplotlib.pyplot as plt
import scipy.integrate as integrate

# %matplotlib inline
import matplotlib.animation as animation

from IPython.display import HTML

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, SimpleRNN
from tensorflow.keras.constraints import max_norm



# TODO should move all this to a module (probably merge with the old cartpole module we were using)

# ball: m = 1 kg
# pole: L = 1 m
# cart: M = 4 kg

g = 9.81  # m/s^2
L = 1.0  # length of the pole (m)
M = 4.0  # mass of the cart (kg)
m = 1  # mass of the ball at the end of the pole (kg)

rad = np.pi / 180
u_hist = []


#animation generation
def animate_pend(y):
    th = y[:,0]
    x1 = y[:,1]
    y1 = 0.0

    x2 = L * sin(th) + x1
    y2 = -L * cos(th) + y1

    fig = plt.figure()
    ax = fig.add_subplot(111, autoscale_on=False, aspect='equal', \
                     xlim=(-3, 3), ylim=(-3, 3))
    ax.grid()

    line, = ax.plot([], [], 'o-', lw=2)
    time_template = 'time = %.1fs'
    time_text = ax.text(0.05, 0.9, '', transform=ax.transAxes)


    def init():
        line.set_data([], [])
        time_text.set_text('')
        return line, time_text


    def animate(i):
        thisx = [x1[i], x2[i]]
        thisy = [y1, y2[i]]

        line.set_data(thisx, thisy)
        time_text.set_text(time_template % (i * dt))
        return line, time_text


    return animation.FuncAnimation(fig, animate, np.arange(1, len(y)), interval=40, blit=True, init_func=init)



# control input: u = F
# q is the state vector
def control(q):
    if (q[0] < 140 * rad) or (q[0] > 220 * rad):
        # swing up
        # energy error: Ee
        Ee = 0.5 * m * L * L * q[2] ** 2 - m * g * L * (1 + cos(q[0]))
        # energy control gain:
        k = 0.23
        # input acceleration: A (of cart)
        A = k * Ee * cos(q[0]) * q[2]
        # convert A to u (using EOM)
        delta = m * sin(q[0]) ** 2 + M
        u = A * delta - m * L * (q[2] ** 2) * sin(q[0]) - m * g * sin(q[2]) * cos(q[2])
    else:
        # balancing
        # LQR: K values from MATLAB
        k1 = 140.560
        k2 = -3.162
        k3 = 41.772
        k4 = -8.314
        u = -(k1 * (q[0] - pi) + k2 * q[1] + k3 * q[2] + k4 * q[3])
        
    return u


# state vector: q = transpose([theta, x, d(theta)/dt, dx/dt])
def derivs(q, t):
    dqdt = np.zeros_like(q)

    # control input
    u = control(q)

    delta = m * sin(q[0]) ** 2 + M

    dqdt[0] = q[2]
    dqdt[1] = q[3]

    dqdt[2] = - m * (q[2] ** 2) * sin(q[0]) * cos(q[0]) / delta \
              - (m + M) * g * sin(q[0]) / delta / L \
              - u * cos(q[0]) / delta / L

    dqdt[3] = m * L * (q[2] ** 2) * sin(q[0]) / delta \
              + m * L * g * sin(q[0]) * cos(q[0]) / delta / L \
              + u / delta

    return dqdt
# Out:
# /Users/sgillen/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# time step
dt = 0.1
t = np.arange(0.0, 20, dt)

rad = np.pi / 180


num_trials = 1
num_states = 4
num_t = len(t)
y = np.zeros((num_t, num_states, num_trials))


for i in range(num_trials):
    # initial conditions
    theta = 0
    x = 0.0
    th_dot = 2*(i/num_trials) - 1  # an initial velocity, triggers the swing up control
    xdot = 0.0

    # initial state
    state = np.array([theta, x, th_dot, xdot])

    # integrate the ODE using scipy.integrate.
    u_hist = []
    y[:, :, i] = integrate.odeint(derivs, state, t)


u = np.zeros((num_t, num_trials))
for i in range(num_trials):
    for t in range(num_t):
        u[t,i] = control(y[t,:,i]) 

        
ani = animate_pend(y[:,:,0])
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img58b2a498d1444b459ab4a2ec5155408f">
#     <br>
#     <input id="_anim_slider58b2a498d1444b459ab4a2ec5155408f" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim58b2a498d1444b459ab4a2ec5155408f.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim58b2a498d1444b459ab4a2ec5155408f.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim58b2a498d1444b459ab4a2ec5155408f.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim58b2a498d1444b459ab4a2ec5155408f.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim58b2a498d1444b459ab4a2ec5155408f.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim58b2a498d1444b459ab4a2ec5155408f.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim58b2a498d1444b459ab4a2ec5155408f.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim58b2a498d1444b459ab4a2ec5155408f.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim58b2a498d1444b459ab4a2ec5155408f.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim58b2a498d1444b459ab4a2ec5155408f.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select58b2a498d1444b459ab4a2ec5155408f" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img58b2a498d1444b459ab4a2ec5155408f";
#     var slider_id = "_anim_slider58b2a498d1444b459ab4a2ec5155408f";
#     var loop_select_id = "_anim_loop_select58b2a498d1444b459ab4a2ec5155408f";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMS4wLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvpW3flQAAFGxJREFUeJzt3X9s1PXhx/HXlQKDtcC60e9ojy2w\
# 4tFdf4HlV1RWMlqsVKEyFjaWzWDS6ZzL8EsVYpxhX4mQ/QgsZJLLZpTF6GQy9DtcSQDPLEPHSopQ\
# Cf12RLb+gAW1BY61cLTv7x+11VqkRY57v9/wfCQmvfNaX1bLk8/dh88FjDFGAAB4JsX2AAAAPg0C\
# BgDwEgEDAHiJgAEAvETAAABeImAAAC8RMACAlwgYAMBLBAwA4CUCBgDwEgEDAHiJgAEAvETAAABe\
# ImAAAC8RMACAlwgYAMBLBAwA4CUCBgDwEgEDAHiJgAEAvETAAABeImAAAC8RMACAlwgYAMBLBAwA\
# 4CUCBgDwEgEDAHiJgAEAvETAAABeImAAAC8RMMd0dnZq5syZKiwsVDgc1uOPP257EgA4KWCMMbZH\
# 4EPGGJ07d05paWmKx+O69dZbtWnTJs2ePdv2NABwCkdgjgkEAkpLS5MkxeNxxeNxBQIBy6sAwD0E\
# zEFdXV0qKipSZmamSktLNWvWLNuTAMA5qbYHYKBhw4bp4MGDam9vV2Vlperr65WXl9fvMZFIRJFI\
# RJL09ttv60tf+pKNqZfU3d2tlBR3fm/EnsG5tsm1Pe+9957effdd2zPwMbwG5ri1a9fqs5/9rFat\
# WvWJjwmFQmpoaEjiqsuLRqMqKSmxPaMPewbn2ibX9hQXF6u2ttb2DHyMO7/FgSTp1KlTam9vlyR1\
# dHRo9+7dmjp1quVVAOAenkJ0zIkTJ/S9731PXV1d6u7u1je/+U1VVFTYngUAziFgjikoKFBdXZ3t\
# GQDgPJ5CBAB4iYABALxEwAAAXiJgAAAvETAAgJcIGADASwQMAOAlAgYA8BIBu8G0t7fr17/+dd/t\
# 1tZWfeMb37C4qMeBAweUn5+vnJwc/ehHP9KlLtF59OhRzZkzRyNHjtTPf/5zCysBuISA3WA+HrCs\
# rCz94Q9/sLiox/33369IJKLGxkY1NjaqpqZmwGMyMjL0q1/96rIXNgZw4yBgN5jVq1fr2LFjKioq\
# UnV1tY4fP973Vi3PPPOMFi9erDvvvFOTJk3S5s2b9ctf/lLTpk3T7Nmz9f7770uSjh07pttvv103\
# 33yzbrvtNh09evSqNp04cUJnzpzRnDlzFAgE9N3vflc7duwY8LjMzEzNmDFDw4cP73f/uXPntHDh\
# QhUWFiovL0+///3vr2oPAD9wLcQbzPr161VfX6+DBw9Kko4fP97v79fX16uurk6dnZ3KycnRhg0b\
# VFdXp5UrV2rr1q368Y9/rKqqKm3ZskVTpkzR3/72N/3gBz/Q3r17+32d1157TStXrhzwzx89erT2\
# 7dvX776WlhYFg8G+28FgUC0tLUP+d6qpqVFWVpZ27twpSTp9+vSQPxeAvwgY+pk3b57S09OVnp6u\
# sWPH6s4775Qk5efn69ChQ4rFYtq3b5+WLl3a9znnz5+/5NfpjeRgLvV6VyAQGPLm/Px8rVq1So88\
# 8ogqKip02223DflzAfiLgKGfkSNH9n2ckpLSdzslJUUXL15Ud3e3xo0bN2icruQILBgMqrm5ue92\
# c3OzsrKyhrz5pptu0oEDB/Tqq69qzZo1Kisr009+8pMhfz4APxGwG0x6errOnj37qT9/zJgxmjRp\
# krZt26alS5fKGKNDhw6psLCw3+Ou5AhswoQJSk9P15tvvqlZs2Zp69atevDBB4e8qbW1VRkZGfrO\
# d76jtLQ0PfPMM1fyrwTAUwTsBvP5z39et9xyi/Ly8lReXq4HHnjgir/Gc889p/vvv19PPPGE4vG4\
# li1bNiBgV+qpp57SPffco46ODpWXl6u8vFyStGXLFknSfffdp5MnT6q4uFhnzpxRS

# %%
# Create our two RNNs for comparison

look_back = 1

# Vanilla
with tf.variable_scope('pi/simple_pol/'):
    simple_model = Sequential()
    simple_model.add(SimpleRNN(12, input_shape=(4,look_back)))
    #model.add(LSTM(12, input_shape =(4,look_back)))
    simple_model.add(Dense(1))

    #model.add(Dense(2))
    

simple_model.compile(loss='mean_squared_error', optimizer='adam')


# LSTM
with tf.variable_scope('pi/simple_pol/'):
    lstm_model = Sequential()
    lstm_model.add(LSTM(12, input_shape =(4,look_back)))
    lstm_model.add(Dense(1))

    #model.add(Dense(2))
    

simple_model.compile(loss='mean_squared_error', optimizer='adam')
lstm_model.compile(loss='mean_squared_error', optimizer='adam')

# %%
simple_history = simple_model.fit(y, u, epochs=500, verbose=0)
plt.plot(simple_history.history['loss'])
plt.title('simple model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.figure()


lstm_history = lstm_model.fit(y, u, epochs=500, verbose=0)
plt.plot(simple_history.history['loss'])
plt.title('lstm model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')

# %%
# This is a closure that returns our NN controller
def make_controller(model):
    def nn_controller(q):
        if (q[0] < 140 * rad) or (q[0] > 220 * rad):
            return model.predict(q.reshape((1,4,1)))
        else:
            # balancing
            # LQR: K values from MATLAB
            k1 = 140.560
            k2 = -3.162
            k3 = 41.772
            k4 = -8.314
            u = -(k1 * (q[0] - pi) + k2 * q[1] + k3 * q[2] + k4 * q[3])
            return u
        
    return nn_controller

# %%
control = make_controller(model)

# initial conditions
theta = 0
x = 0
th_dot = .01 # an initial velocity, triggers the swing up control
xdot = 0.0
t = np.arange(0.0, 20, dt)


# initial state
state = np.array([theta, x, th_dot, xdot])

# integrate the ODE using scipy.integrate.
y_test = integrate.odeint(derivs, state, t)

#ani = animate_pend(y_test)
#HTML(ani.to_html5_video())

# %%
def run_swingup():
    control = make_controller(model)
    
    # initial conditions
    theta = 0
    x = 0
    th_dot = .01 # an initial velocity, triggers the swing up control
    xdot = 0.0
    t = np.arange(0.0, 20, dt)


    # initial state
    state = np.array([theta, x, th_dot, xdot])

    # integrate the ODE using scipy.integrate.
    y_test = integrate.odeint(derivs, state, t)

    #ani = animate_pend(y_test)
    #HTML(ani.to_html5_video())

# %%
control = make_controller(model)

# initial conditions
theta = 0
x = 0
th_dot = .01 # an initial velocity, triggers the swing up control
xdot = 0.0
t_index = np.arange(0.0, 20, dt)


# initial state
state = np.array([theta, x, th_dot, xdot])

# integrate the ODE using scipy.integrate.
# Fill in our u after the fact..
y_test = integrate.odeint(derivs, state, t_index)
u_test = np.zeros((y.shape[0],1))
for t in range(num_t):
        u_test[t] = control(y[t]) 

        
data = np.concatenate((y_test, u_test),axis=1)
names = ['theta','x','thetadot','xdot','u']
yf = pd.DataFrame(data = data, index = t_index, columns = names)


ani = animate_pend(y_test)
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img682c1cdbc3234ab2938b3eb198c004a2">
#     <br>
#     <input id="_anim_slider682c1cdbc3234ab2938b3eb198c004a2" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim682c1cdbc3234ab2938b3eb198c004a2.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim682c1cdbc3234ab2938b3eb198c004a2.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim682c1cdbc3234ab2938b3eb198c004a2.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim682c1cdbc3234ab2938b3eb198c004a2.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim682c1cdbc3234ab2938b3eb198c004a2.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim682c1cdbc3234ab2938b3eb198c004a2.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim682c1cdbc3234ab2938b3eb198c004a2.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim682c1cdbc3234ab2938b3eb198c004a2.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim682c1cdbc3234ab2938b3eb198c004a2.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim682c1cdbc3234ab2938b3eb198c004a2.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select682c1cdbc3234ab2938b3eb198c004a2" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img682c1cdbc3234ab2938b3eb198c004a2";
#     var slider_id = "_anim_slider682c1cdbc3234ab2938b3eb198c004a2";
#     var loop_select_id = "_anim_loop_select682c1cdbc3234ab2938b3eb198c004a2";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMS4wLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvpW3flQAAFCVJREFUeJzt3X9s1PXhx/HXlQKBtcgwa0Z7uMiK\
# 1/P6C2z5kSkrCW1XqUBh+mVj2Ywmnc5tmYY6DdkMiwSI2wIL0eayGWQhc2NjaIYpGeKRZaispAyr\
# oemIuP6QxG1UeqSlR/v+/oE9LQVabLn3+y3PR2LSnm190fjhyedzH64BY4wRAACeSbM9AACAT4OA\
# AQC8RMAAAF4iYAAALxEwAICXCBgAwEsEDADgJQIGAPASAQMAeImAAQC8RMAAAF4iYAAALxEwAICX\
# CBgAwEsEDADgJQIGAPASAQMAeImAAQC8RMAAAF4iYAAALxEwAICXCBgAwEsEDADgJQIGAPASAQMA\
# eImAAQC8RMAAAF4iYAAALxEwAICXCBgAwEsEzDG9vb2aP3++ioqKFIlE9NRTT9meBABOChhjjO0R\
# +JgxRufOnVNGRoYSiYTuvPNObdu2TQsXLrQ9DQCcwhmYYwKBgDIyMiRJiURCiURCgUDA8ioAcA8B\
# c1B/f7+Ki4uVlZWl8vJyLViwwPYkAHBOuu0BGG7ChAk6duyYurq6VFNTo+bmZuXn5w/5mGg0qmg0\
# Kkl6++23dcstt9iYelkDAwNKS3Pnz0bsGZlrm1zb89///lf/+c9/bM/AJXgOzHEbNmzQ5z73Oa1b\
# t+6KHxMKhdTS0pLCVVcXi8VUVlZme0YSe0bm2ibX9pSUlKixsdH2DFzCnT/iQJL0wQcfqKurS5LU\
# 09OjAwcOKC8vz/IqAHAPlxAd8/777+s73/mO+vv7NTAwoPvuu0/V1dW2ZwGAcwiYYwoLC9XU1GR7\
# BgA4j0uIAAAvETAAgJcIGADASwQMAOAlAgYA8BIBAwB4iYABALxEwAAAXiJgN5iuri49++yzyfc7\
# Ozv19a9/3eKii44ePaqCggLl5ubqhz/8oS73Ep0nTpzQokWLNHnyZP385z+3sBKASwjYDebSgGVn\
# Z+uPf/yjxUUXPfzww4pGo2ptbVVra6saGhqGfcyMGTP0q1/96qovbAzgxkHAbjBPPPGETp48qeLi\
# YtXV1enUqVPJH9WyY8cOrVy5Uvfcc49uvfVWbd++Xb/85S81d+5cLVy4UP/73/8kSSdPntTXvvY1\
# 3XHHHbrrrrt04sSJMW16//33dfbsWS1atEiBQEDf/va3tXfv3mEfl5WVpdLSUk2cOHHI4+fOndOy\
# ZctUVFSk/Px8/f73vx/THgB+4LUQbzCbN29Wc3Ozjh07Jkk6derUkH/f3NyspqYm9fb2Kjc3V1u2\
# bFFTU5MeffRR7dy5Uz/60Y9UW1ur+vp6zZkzR2+++aa+973v6eDBg0O+zmuvvaZHH3102H9/6tSp\
# Onz48JDHOjo6FAwGk+8Hg0F1dHSM+tfU0NCg7Oxs7du3T5L04YcfjvpzAfiLgGGIJUuWKDMzU5mZ\
# mbrpppt0zz33SJIKCgp0/PhxxeNxHT58WPfee2/yc86fP3/ZrzMYyZFc7vmuQCAw6s0FBQVat26d\
# fvzjH6u6ulp33XXXqD8XgL8IGIaYPHly8u20tLTk+2lpabpw4YIGBgY0ffr0EeN0LWdgwWBQ7e3t\
# yffb29uVnZ096s233Xabjh49qldeeUVPPvmkKioq9NOf/nTUnw/ATwTsBpOZmanu7u5P/fnTpk3T\
# rbfeqt27d+vee++VMUbHjx9XUVHRkI+7ljOwmTNnKjMzU2+88YYWLFignTt36gc/+MGoN3V2dmrG\
# jBn61re+pYyMDO3YseNafkkAPEXAbjA333yzvvKVryg/P19VVVV65JFHrvlr7Nq1Sw8//LCefvpp\
# JRIJrVmzZljArtVzzz2n+++/Xz09PaqqqlJVVZUkqb6+XpL00EMP6fTp0yopKdHZs

# %%
plt.plot(yf['state','theta'])
old_theta = yf['state','theta']

# %%
new_theta = yf['theta']

# %%
np.all(old_theta == new_theta)

# %%
N_train = 1000
from numpy.random import choice
one_indexes = choice(a=N_train, size=int(N_train / 2), replace=False)
X_train[one_indexes, 0] = 1  # very long term memory.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-180f41d8c0e6> in <module>
#       2 from numpy.random import choice
#       3 one_indexes = choice(a=N_train, size=int(N_train / 2), replace=False)
# ----> 4 X_train[one_indexes, 0] = 1  # very long term memory.
#
# NameError: name 'X_train' is not defined

# %%
# messing with multiindexing 
# TODO probably move this to the misc folder, preferably as a more complete example than this one.

names = [
    ('state', 'theta'),
    ('state', 'x'),
    ('state', 'thetadot'),
    ('state', 'xdot'),
    ('control' ,'u')
]

yf = pd.DataFrame(data = data, index = t_index, columns=pd.MultiIndex.from_tuples(names))
